# %% [markdown]
# # Libraries installation

# %% [markdown]
# Install Transformers libaries, framework seqeval, some extensions: unidecode for formatting accent language, datasets for creating a Dataset,...

# %%
#Install required libraries
# !pip install datasets transformers evaluate seqeval unidecode
# Out:
# Installing collected packages: tokenizers, xxhash, unidecode, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, seqeval, aiohttp, datasets, evaluate
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 seqeval-1.2.2 tokenizers-0.13.3 transformers-4.28.1 unidecode-1.3.6 xxhash-3.2.0 yarl-1.9.2

# %% [markdown]
# Import required libraries

# %%
#Import libraries to project
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainer, TrainingArguments, Seq2SeqTrainingArguments
import torch
from datasets import Dataset
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader
import json
import pandas as pd
from unidecode import unidecode

# %% [markdown]
# Mount Google Drive to Google Colab

# %%
#Mount Drive to Colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Data preparation

# %% [markdown]
# Read training set from dataset stored in Google Drive.
# Create a list of input and output sequences

# %%
#Read training set 
trainWord = [json.loads(line) for line in open('gdrive/MyDrive/Ct550/word/train_word.json', 'r', encoding='utf-8')]
trainWordData = pd.DataFrame(trainWord)

# %%
#Create a list of texts
inputs = trainWordData['words']
input_sequences = []

for sentence in inputs:
  input_sequences.append(' '.join(sentence))

# %% [markdown]
# Convert problem into text-to-text format by formatting an output which is a sequence of class:entity pairs separated by a semicolon ';'

# %%
def format_targets(text, label):
  s = ""
  texts = []
  for i in range(len(text)-1):
    if label[i] != 'O':
      s += text[i] + " "
      if label[i+1] == 'O' or label[i+1][0:1] == 'B':
        s = label[i][2:] + ": " + s
        texts.append(s.strip())
        s = ""
  texts = "; ".join(texts)
  return texts

# %%
str1 = format_targets(text, label)
str1
# Out:
# 'DATE: 12/8; DATE: 20/8'

# %% [markdown]
#  Convert them back to sentence format

# %%
output_sequences = []
for i in range(5027):
  text = trainWordData['words'][i]
  label = trainWordData['tags'][i]

  target = format_targets(text, label)
  output_sequences.append(target)

# %%
input_sequences[4089], output_sequences[4089]
# Out:
# ('Bệnh_nhân vào viện ngày 31/7 , đến nay đã 4 lần xét_nghiệm âm_tính với nCoV , gồm lần một ngày 6/8 , lần hai ngày 8/8 , lần ba ngày 10/8 , lần bốn ngày 11/8 .',
#  'DATE: 31/7; DATE: 6/8; DATE: 8/8; DATE: 10/8; DATE: 11/8')

# %% [markdown]
# # Training preparation

# %% [markdown]
# We first load a ViT5 tokenizer and a pretrained model powered by Transformers library

# %%
#Create a tokenizer and a model supported by ViT5
tokenizer = AutoTokenizer.from_pretrained("VietAI/vit5-base")  
model = AutoModelForSeq2SeqLM.from_pretrained("VietAI/vit5-base")
# model.to("cuda")

# %% [markdown]
# Define a function which converts data to tokens

# %%
#Function for tokenizing texts and labels
def preprocess(examples):
  model_inputs = tokenizer(
      examples["inputs"], max_length=256, truncation=True, padding=True
  )
  with tokenizer.as_target_tokenizer():
    labels = tokenizer(
        examples["labels"], max_length=256, truncation=True, padding=True
    )
  model_inputs["labels"] = labels['input_ids']
  model_inputs['input_ids'] = model_inputs['input_ids']
  return model_inputs

# %% [markdown]
# Define a dictionary that holds inputs and their corresponding labels
#
# Create a dataset from that dictionary and apply the tokenization process to every data sample with map function

# %%
#Tokenise dataset
dict_obj = {'inputs':input_sequences, 'labels':output_sequences}
dataset = Dataset.from_dict(dict_obj)
tokenized_datasets = dataset.map(preprocess, batched=True, num_proc=8)

# %% [markdown]
# Set training arguments for training process

# %%
#Arguments for training model
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="pt")
training_args = Seq2SeqTrainingArguments('gdrive/MyDrive/checkpoint',
                                      do_train=True,
                                      do_eval=False,
                                      num_train_epochs=10,
                                      learning_rate=2e-5,
                                      warmup_ratio=0.00,
                                      weight_decay=0.01,
                                      per_device_train_batch_size=4,
                                      per_device_eval_batch_size=4,
                                      logging_dir='./log',
                                      group_by_length=True,
                                      save_strategy="epoch",
                                      save_total_limit=3,
                                      #eval_steps=1,
                                      #evaluation_strategy="steps",
                                      # evaluation_strategy="no",
                                      # fp16=True,
                                      )

# %% [markdown]
# Make sure to push the model to GPU for optimisation

# %%
model.to('cuda')

# %% [markdown]
# # Train Named Entity Recognition model

# %%
#Procession of training model 
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets,
    data_collator=data_collator,
)

trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='12570' max='12570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12570/12570 1:35:50, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.637600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.031100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.016300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.012600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.010400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.007600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.003300</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.003100</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.002200</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.000800</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.000700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=12570, training_loss=0.030352786416002656, metrics={'train_runtime': 5754.3935, 'train_samples_per_second': 8.736, 'train_steps_per_second': 2.184, 'total_flos': 1.1147259635712e+16, 'train_loss': 0.030352786416002656, 'epoch': 10.0})

# %% [markdown]
# # Inference

# %% [markdown]
# Load fine-tuned model stored in Google Drive with a Tokenizer by ViT5

# %%
#Load model saved as a checkpoint
from transformers import AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained('VietAI/vit5-base')
model = AutoModelForSeq2SeqLM.from_pretrained("gdrive/MyDrive/checkpoint/checkpoint-12570")
# model.to("cuda")

# %%
#Total number of trainable parameters
pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
pytorch_total_params
# Out:
# 225950976

# %%
model.to('cpu')

# %% [markdown]
# To use the model at its best, make sure the data fed to the model is word-level,
#  if it's not, simply use an RDR-Segmenter!

# %%
# !pip install python-rdrsegmenter

# %%
from python_rdrsegmenter import load_segmenter
segmenter = load_segmenter()
text = "Bệnh nhân 651 , quê Duy Xuyên , Quảng Nam , có tiền sử suy thượng thận mạn tính ."
segmenter.tokenize(text)
# Out:
# 'Bệnh_nhân 651 , quê Duy_Xuyên , Quảng_Nam , có tiền_sử suy thượng_thận mạn_tính .'

# %% [markdown]
# The cell below helps produce target text with 'generate' method

# %%
sentence = input('Your sentence: ')
# sentence = eval_input_sequences[23]
encoding = tokenizer(sentence, return_tensors="pt", max_length=1024)
input_ids, attention_masks = encoding["input_ids"], encoding["attention_mask"]
outputs = model.generate(
    input_ids=input_ids, attention_mask=attention_masks,
    max_length=1024,
)
labels = tokenizer.decode(outputs[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)
print ("Results: ")
labels
# Out:
# Your sentence: Bệnh_nhân 315 là một y_tá bệnh_viện Chợ_Rẫy
# Results:
# 'PATIENT_ID: 315'

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# 'word_labels' takes into account two parameters 'sentence' and 'labels' to calculate the correct BIO label and map them to a list

# %%
def word_labels(sentence, labels):
  predictions = ["O" for i in range(len(sentence.split()))]
  if labels != '':
    list_labels = labels.split(";")
    sent = sentence.split()

    start = 0
    for i in range(len(list_labels)):
      sub_list = list_labels[i].split(":")
      class_entity = sub_list[0].strip() # location, organization, age,...
      named_entity = sub_list[1].strip().lower() # Ha Noi, London, 433,...
      named_entity_element = named_entity.split() # Ha, Noi, London, 433, Soc Trang,...

      flist = []
      for i in range(len(named_entity_element)):
        if named_entity_element[i][-1] == ',':
          entity1 = named_entity_element[i][0:len(named_entity_element[i])-1]
          entity2 = ","
          flist.append(entity1)
          flist.append(entity2)
        else:
          flist.append(named_entity_element[i])

      named_entity_element = flist
      for i in range(len(named_entity_element)): 
        try:
          findex = sent.index(named_entity_element[i], start)
          start = findex + 1
          f_class = ""
          if i == 0:
            f_class = "B-" + class_entity
          else:
            f_class = "I-" + class_entity
          predictions[findex] = f_class
        except:
          pass

  return predictions

# %% [markdown]
# # reverse the subword tokens to their real words

# %% [markdown]
# Load dataset for devaluation

# %%
#Read test set
evalWord = [json.loads(line) for line in open('gdrive/MyDrive/Ct550/word/test_word.json', 'r', encoding='utf-8')]
evalWordData = pd.DataFrame(evalWord)
evalWordData = evalWordData.rename(columns={'tags':'target_text', 'words':'source_text'})

# %% [markdown]
# Create lists of input and output sequences

# %%
#Create a list of texts
eval_input_data = evalWordData['source_text']
eval_input_sequences = []

for sentence in eval_input_data:
  eval_input_sequences.append(" ".join(sentence))

#Create a list of targets
eval_output_data = evalWordData['target_text']
eval_output_sequences = []

for sentence in eval_output_data:
  eval_output_sequences.append(" ".join(sentence))

# %%
eval_input_sequences
# Out:
# ['Từ 24 - 7 đến 31 - 7 , bệnh_nhân được mẹ là bà H.T.P ( 47 tuổi ) đón về nhà ở phường Phước_Hoà ( bằng xe_máy ) , không đi đâu chỉ ra Tạp_hoá Phượng , chợ Vườn_Lài , phường An_Sơn cùng mẹ bán tạp_hoá ở đây .',
#  'Bác_sĩ Trần_Thanh_Linh , từ Bệnh_viện Chợ_Rẫy chi_viện phụ_trách đơn_nguyên hồi_sức tích_cực , cho biết " bệnh_nhân 416 " vẫn đang duy_trì ECMO , thở máy , hiện xơ phổi rất nhiều .',
#  'Theo đó , Sở Y_tế Bình_Thuận cho biết sau khi xác_định bệnh_nhân số 34 ( nữ_giới 51 tuổi , từ Mỹ về Việt_Nam ngày 29 - 2 có quá_cảnh Qatar ) , Trung_tâm Kiểm_soát bệnh_tật Bình_Thuận đã điều_tra dịch_tễ , khoanh vùng , khử khuẩn , tiến_hành cách_ly người liên_quan đến ca bệnh số 34 .',
#  'Bệnh_nhân 218 : nữ , 43 tuổi , quốc_tịch Việt_Nam , địa_chỉ tại Phú_Xá , Thái_Nguyên , về nước trên chuyến bay SU290 ( số ghế 46 G ) ngày 25 - 3 , sau nhập_cảnh được cách_ly tập_trung tại Đại_học FPT ở Láng - Hoà_Lạc ( Hà_Nội ) . Từ 31 - 3 bệnh_nhân được cách_ly , điều_trị tại Bệnh_viện Bệnh nhiệt_đới trung_ương cơ_s
#  'Thiếu_nữ trú phường Nghĩa Trung , TP Gia_Nghĩa , có yếu_tố dịch_tễ là tiếp_xúc với người từ vùng dịch trở về .',
#  'Ca số 20 và 161 đang được điều_trị tại Bệnh nhiệt_đới Trung_ương cơ_sở 2 .',
#  'Trước đó vào ngày 30 - 8 , T.T.B.P. nhập_cảnh vào Nhật_Bản , được xét_nghiệm và có kết_quả dương_tính với virus SARS - CoV - 2 .',
#  'Bộ_trưởng Bộ Kế_hoạch - đầu_tư Nguyễn_Chí_Dũng là một trong những người đi cùng chuyến bay số_hiệu VN0054 của VietNam_Airlines , hạ_cánh xuống sân_bay Nội_Bài lúc 4h30 sáng 2 - 3 , ngồi cùng khoang hạng thương_gia với nữ bệnh_nhân N.H.N ..',
#  '3 . Những người đi chuyến tàu 23h ngày 21 - 7 , số_hiệu SE7 từ thành_phố Đà_Nẵng đến thành_phố Quảng_Ngãi .',
#  'Các ca tiên_lượng nặng gồm bà_cụ 88 tuổi bị tai_biến mạch_máu não , bệnh_nhân người Thuỵ_Điển 64 tuổi ung_thư máu , và bệnh_nhân 71 tuổi người Vĩnh_Phúc ung_thư gan .',
#  'Theo ông Thạch , có 2 trong số 8 bệnh_nhân COVID - 19 tái dương_tính đang được cách_ly tại Bệnh_viện Bệnh nhiệt dới trung_ương ( bệnh_nhân 188 và 237 ) , với những thay_đổi liên_tục về xét_nghiệm : ra viện ngày 16 - 4 , 17 - 4 dương_tính lại , 18 - 4 âm_tính nhưng 20 và 21 - 4 lại dương_tính .',
#  'Mới_đây tại Việt_Nam , thông_tin đáng chú_ý trong sàng_lọc , phát_hiện bệnh_nhân thứ 13 , vừa có xét_nghiệm xác_định dương_tính tối 7 - 2 : bệnh_nhân không sốt , không ho , không có biểu_hiện bệnh nhưng vẫn nhiễm virus corona .',
#  '" Bệnh_nhân 976 " , nam , 42 tuổi , địa_chỉ tại Thạch_Sơn , Thạch_Thành , Thanh_Hoá .',
#  'Trong đêm 6 - 8 , bệnh_nhân được chuyển từ khoa truyền_nhiễm của Bệnh_viện Đa_khoa tỉnh Hải_Dương tới Bệnh_viện Bệnh nhiệt_đới trung_ương .',
#  'Ngày 24/7 , bệnh_nhân chăm_sóc bố là " bệnh_nhân 428 " tại khoa Nội - Tiết_niệu , Bệnh_viện Đà_Nẵng .',
#  '" Bệnh_nhân 63 " là nữ , 20 tuổi , ở C2 Chung_cư Mandarin_Garden , đường Hoàng_Minh_Giám , phường Trung_Hoà , Quận Cầu_Giấy , Hà_Nội .',
#  'Vào ngày 9 - 3 , Sở Y_tế Đà_Nẵng mới nhận được văn_bản hoả_tốc của Ban chỉ_đạo quốc_gia về phòng_chống dịch COVID - 19 , trong đó có nội_dung " nâng_cấp độ " cách_ly ( yêu_cầu những người tiếp_xúc gần với trường_hợp bệnh_nhân dương_tính với COVID - 19 phải được tổ_chức cách_ly ngay tại cơ_sở y_tế trong vòng 14 ngày , đồng_thời lấy mẫu bệnh_phẩm để xét_nghiệm khẳng_định ) .',
#  '" Bệnh_nhân này là công_nhân làm_việc ở Công_ty Samsung tại huyện Yên_Phong , tỉnh Bắc_Ninh .',
#  'Hôm 9 - 2 , sau khi tình_trạng nữ bệnh_nhân tiếp_tục chuyển_biến xấu , có biểu_hiện suy tạng , các bác_sĩ bắt_đầu sử_dụng liệu_pháp tế_bào gốc để điều_trị sau khi tham_khảo ý_kiến từ bệnh_viện và gia_đình bệnh_nhân .',
#  '" Bệnh_nhân 1013 " , 51 tuổi , tiểu_thương bán hải_sản ở chợ Siêu_Thị , từng được lấy mẫu xét_nghiệm nCoV lần một ngày 16/8 và có kết_quả âm_tính .',
#  'Khoảng 6h sáng 28 - 7 , bà xuống xe tại Lưu_Vệ , Quảng_Xương và tự đi xe_máy về ( xe_máy gửi trên ôtô từ Đà_Nẵng về ) .',
#  '9h sáng nay , nhân_viên y_tế đã phun thuốc khử_trùng tại nhà của bệnh_nhân trên đường Hải_Sơn ( tổ 25 , phường Thanh_Bình ) , sau đó tiếp_tục phun thuốc tại Trung_tâm y_tế quận Hải_Châu trên đường Cao_Thắng , nơi bệnh_nhân đến khám .',
#  'Thân_nhân bệnh_nhân 94 đang có kết_quả âm_tính Chị Nguyễn_Thị_Diệu_Linh cho biết chiều 21 - 3 , ngay khi Việt_Nam công_bố ca bệnh 94 dương_tính với COVID - 19 là nữ , 64 tuổi , quốc_tịch Việt_Nam sang CH Czech thăm con gái từ ngày 29 - 2 đến ngày 17 - 3 , Hội Thanh_niên , sinh_viên Việt_Nam tại Czech đã tìm ra thân_nhân của bệnh_nhân 94 .',
#  'Bệnh_nhân đi Malaysia ngày 27 - 2 và về Việt_Nam ngày 4 - 3 trên chuyến bay VJ826 từ Malaysia về sân_bay quốc_tế Tân_Sơn_Nhất ( TP. HCM ) .',
#  'Hà_Tĩnh đến nay ghi_nhận 3 ca nhiễm nCoV , là bệnh_nhân 146 , 210 và 238 , đang điều_trị tại Bệnh_viện Đa_khoa cửa_khẩu Cầu_Treo .',
#  'Ông có tiền_sử bị phổi tắc_nghẽn mạn_tính ( COPD ) và u ác niệu_quản đã phẫu_thuật cách đây hai năm .',
#  'Trong đó " bệnh_nhân 892 " là chồng , " bệnh_nhân 893 " là vợ , " bệnh_nhân 894 , 895 " là hai con gái , " bệnh_nhân 896 " là mẹ chồng .',
#  'Cuối tháng 5 , cô từ Hàn_Quốc về Việt_Nam , cách_ly tập_trung tại huyện Hoà_Vang , thành_phố Đà_Nẵng , xét_nghiệm hai lần kết_quả đều âm_tính .',
#  'Thiếu máu có_thể gây tử_vong cho các bệnh_nhân cần phẫu_thuật , nạn_nhân của các tai_nạn xe_hơi cũng như các trường_hợp khẩn_cấp khác , hoặc bệnh_nhân ung_thư .',
#  'Biết thông_báo rà_soát các trường_hợp từ Đà_Nẵng về , sáng 29/7 ông đến Bệnh_viện Nhiệt_đới Trung_ương 2 để lấy mẫu xét_nghiệm và có kết_quả dương_tính với Covid - 19 .',
#  'Theo rà_soát của Sở Y_tế tỉnh Thanh_Hoá , từ ngày 15 đến 26/3 , địa_phương này có gần 1.900 bệnh_nhân đến khám , chữa bệnh tại bệnh_viện Bạch_Mai , trong đó 150 bệnh_nhân điều_trị nội_trú .',
#  'Ngày 17 - 3 , lực_lượng chức_năng phường 7 đã phối_hợp Trung_tâm Kiểm_soát bệnh_tật TP. HCM khử_trùng y_tế và dựng rào_chắn phong_toả , cách_ly hẻm 248 đường Phạm_Ngũ_Lão , nơi bệnh_nhân sinh_sống .',
#  'Các bệnh_nhân 17 , 21 , 32 sức_khoẻ đang tiến_triển tốt Mạng xã_hội có nhiều tin_đồn về sức_khoẻ các bệnh_nhân COVID - 19 đang được điều_trị , đặc_biệt là bệnh_nhân 17 N.H.N. , bệnh_nhân 21 N.Q.T. và bệnh_nhân 32 N.T.T ..',
#  'Ngày 9/3 , Ban chỉ_đạo phòng , chống dịch_bệnh thành_phố Đà_Nẵng cho_hay , sau khi đến Hà_Nội trên chuyến bay VN54 hôm 2/3 , hai nam du_khách người Anh ( 60 và 66 tuổi ) đã đáp chuyến bay VN163 đến Đà_Nẵng lúc 10h20 cùng ngày ( ghế 2C và 2 A ) .',
#  'Bác_sĩ Nguyễn_Ngọc_Sang ( khoa bệnh nhiệt_đới Bệnh_viện Chợ_Rẫy ) , một trong các bác_sĩ được chọn chăm_sóc , điều_trị cho hai bệnh_nhân Trung_Quốc nhiễm virus corona trong phòng cách_ly đặc_biệt , cho biết : " Về bệnh_lý , người cha được xác_định nằm trong diện có nhiều nguy_cơ rơi vào diễn_tiến nặng dẫn đến tử_vong cao khi " hội_tụ " các yếu_tố lớn_tuổi , có nhiều bệnh nền như ung_thư phổi , đái_tháo_đường , bệnh mạch vành đặt 2 - 3 stent và tăng huyết_áp … .',
#  'Đến ngày 28/7 , cô cùng chống đến Trạm y_tế phường An_Hải_Bắc để khai_báo y_tế và về tự cách_ly ở nhà .',
#  'Cô là chị và sống cùng nhà với bệnh_nhân 127 ( nam nhân_viên quán bar Buddha ) , làm_việc tại Công_ty Formica - tầng 3 , toà nhà 414 Nguyễn_Thị_Minh_Khai , phường 5 , quận 3 , TP.HCM.',
#  'Bệnh_nhân tử_vong bên đường Đa_Phú , 2 bệnh_nhân còn lại ở chợ Đà_Lạt .',
#  'Ngày 21 - 7 , bệnh_nhân đi ăn giỗ tại số 3 Lê_Văn_Long .',
#  'Ngoài_ra trong ngày 21 - 9 có 5 bệnh_nhân được công bố khỏi bệnh , gồm 1 bệnh_nhân tại Bệnh viện dã chiến Hòa Vang ( Đà_Nẵng ) , 2 bệnh nhân tại Bệnh viện Bệnh nhiệt đới trung ương cơ sở Đông Anh ( Hà_Nội ) , 1 bệnh_nhân tại Bệnh viện Bệnh nhiệt đới tỉnh Hải Dương và 1 bệnh_nhân tại Bệnh viện Lao và bệnh phổi Cần Thơ .',
#  'Thông_tin về 2 ca nhiễm SARS - CoV - 2 mới , ông Hiền cho biết bệnh_nhân L.M.H. ( 36 tuổi , ở huyện Thường_Tín ) có tiền_sử tới Bệnh_viện Bạch_Mai vào ngày 10 - 3 thăm mẹ điều_trị bệnh .',
#  '" Bệnh_nhân 197 " , nam 41 tuổi , ở khu đô_thị Thanh_Hà , Cự_Khê , Thanh_Oai , Hà_Nội , ngày 12/3 tới khám tại Trung_tâm Bệnh Nhiệt_đới Bệnh_viện Bạch_Mai .',
#  'Ngày 20 - 7 , anh L. và chị H. đi uống cà_phê tại quán Chip_Còi ở thị_trấn Hồ Xá , Vĩnh_Linh .',
#  'Ngày 3/8 , bệnh_nhân lơ_mơ , thể_trạng suy_kiệt , loét vùng cẳng_tay và cẳng bàn_chân , xuất_huyết dưới da cẳng_tay hai bên , khó thở nhẹ .',
#  'Ngày 2 - 8 , anh V.V.M. ( 35 tuổi , ngụ xã Hữu_Kiệm ) từ Hà_Nội ( địa_phương đang có ca dương_tính COVID - 19 ) trở về Kỳ_Sơn , chính_quyền địa_phương nắm_bắt thông_tin và yêu_cầu anh M. đến cơ_sở y_tế để khai_báo lịch_sử di_chuyển nhưng M. không chấp_hành .',
#  'Trong khi đó , bệnh_nhân 203 là người từ Hi_Lạp về và đang được cách_ly , điều_trị tại TP.HCM.',
#  'Đến ngày 20 - 3 , biết thông_tin về bệnh_nhân 91 , anh tới Phòng_khám đa_khoa FV Sài_Gòn ( quận 1 ) để khai_báo tiền_sử dịch_tễ , sau đó được chuyển đến Bệnh_viện Bệnh nhiệt_đới TP. HCM cách_ly , lấy mẫu xét_nghiệm và chưa ghi_nhận triệu_chứng bệnh .',
#  'Chị là người_nhà đến chăm_sóc điều_trị tại tầng 3 Khoa_Nội thận - Tiết_niệu , Bệnh_viện C vào các buổi sáng và chiều_tối từ ngày 16 đến 23/7 .',
#  'Những người này làm_việc ở Vinpearl_Golf_Nam_Hội An hôm 5/3 và tiếp_xúc với " bệnh_nhân 22 " , " bệnh_nhân 23 " .',
#  'Trước đó , CDC tỉnh Nghệ_An đã lấy mẫu xét_nghiệm nCoV 132 người liên_quan " bệnh_nhân 736 " , kết_quả xét_nghiệm âm_tính lần một .',
#  'Suy đa tạng dẫn đến nhiễm_trùng , đẩy bệnh_nhân vào tình_trạng tiếp_tục suy các cơ_quan tạng khác , thậm_chí có những cơ_quan không_thể hồi_phục được vì đã ở giai_đoạn cuối .',
#  'Trường_hợp bệnh_nhân 64 ( ngụ phường 2 , quận 8 ) : tổng_số người tiếp_xúc 88 , trong đó 20 người tiếp_xúc trên chuyến bay EK392 đang xác_minh .',
#  'Tại buổi họp , bà Nguyễn_Thị_Kiều_Anh - phó giám_đốc Trung_tâm kiểm_soát bệnh_tật TP Hà_Nội - nói mặc_dù Việt_Nam chưa ghi_nhận thêm ca bệnh mới so với con_số 16 bệnh_nhân nhưng Hà_Nội có lưu_lượng người đi về từ các quốc_gia khác nhau lớn nên nguy_cơ lây_lan dịch_bệnh vẫn còn .',
#  'Các bác_sĩ cho biết ca này không liên_quan đến chợ Hoa_Nam nhưng chợ là nơi virus đã lây_lan diện rộng .',
#  'Tối 5 - 5 , bác_sĩ Trương_Thanh_Trung - trưởng Phòng y_tế quận 2 , TP. HCM - xác_nhận với Tuổi_Trẻ Online bệnh_nhân 204 đã dương_tính trở_lại sau 25 ngày xuất_viện sau điều_trị COVID - 19 .',
#  'Ngày 29 - 2 , bệnh_nhân bay từ Washington về sân_bay Doha ( Qatar ) trên chuyến bay Qatar Aiways QR 708 để quá_cảnh .',
#  'Tổng_cộng 145 người đã từng tiếp_xúc với anh ta , bao_gồm : nơi làm_việc 132 người ( đồng_nghiệp , lãnh_đạo công_ty , lái_xe , công_nhân ) , nơi lưu_trú khách_sạn ( 7 người ) , tại quán ăn ( 2 người ) , phòng_khám Family_Medical_Practice quận 2 ( 4 người ) .',
#  'Một ngày sau , bà được cách_ly tại khoa Nội_Thận – Tiết_niệu , Bệnh_viện Đà_Nẵng .',
#  'Trong tháng 7 , bệnh_nhân đi làm tại Trung_tâm hành_chính Đà_Nẵng các ngày 22 , 23 , 24 , 27 , tiếp_xúc với nhiều đồng_nghiệp trong cơ_quan .',
#  '" Bệnh_nhân 813 " , nữ 35 tuổi , công_nhân dệt_may , trú ở đường Ông Ích_Đường , phường Khuê_Trung , quận Cẩm_Lệ .',
#  'Ngày 8/8 , chị chở bố ( 56 tuổi ) bị sốt đến khám tại Trạm Y_tế xã Hoà_Tiến .',
#  '" Ngày 4 - 8 , bệnh_nhân đến khám tại Bệnh_viện Bệnh nhiệt_đới trung_ương , cơ_sở 2 Đông_Anh và đến sáng 5 - 8 , bệnh_viện công_bố kết_quả xét_nghiệm lần 1 dương_tính với COVID - 19 " - ông Việt cho_hay .',
#  '" Bệnh_nhân 430 " , nữ , 33 tuổi , địa_chỉ phường Hải_Châu , quận Hải_Châu , thành_phố Đà_Nẵng , tiền_sử suy thận mạn giai_đoạn cuối , suy tim , tăng huyết_áp , nhiễm_trùng huyết .',
#  '18h ngày 7/5 , Bộ Y_tế ghi_nhận 17 ca nhiễm nCoV , đều là người Việt đi chung chuyến bay VN0088 từ Các Tiểu vương_quốc Arab_Thống nhất về Bạc_Liêu , cách_ly tập_trung ngay .',
#  '5 người chết vào 3/4 , 5 người vào 2/4 , 4 người ngày 1/4 , 2 người vào 31/3 , 5 người vào 30/3 và 3 người vào 29/3 .',
#  'Trường_hợp 2 ( bệnh_nhân số 440 ) : nữ 40 tuổi , ở thôn Hoà_Hữu_Tây , xã Đại_Hồng , huyện Đại_Lộc , tỉnh Quảng_Nam , là nội_trợ .',
#  'Viện Pasteur_Nha_Trang ngày 14/3 thông_báo mẫu xét_nghiệm do Trung_tâm kiểm_soát bệnh_tật tỉnh Thừa_Thiên - Huế gửi , dương_tính nCoV .',
#  'Mẫu được gửi Viện Vệ_sinh Dịch_tễ trung_ương ngày 21 - 7 cho kết_quả dương_tính với SARS - CoV - 2 .',
#  'Đó là bà L.T.H , sinh năm 1956 , là bác ruột của bệnh_nhân N.H.N. và anh D.Đ.P , sinh năm 1993 , là lái_xe riêng của gia_đình .',
#  'Liên_quan đến bệnh_nhân COVID - 19 thứ 912 người Trung_Quốc nhập_cảnh trái_phép , lãnh_đạo UBND quận Tân_Bình cho biết bệnh_nhân này đã tiếp_xúc với 50 công_an tại phường 1 , phường 2 ( quận Tân_Bình ) và 13 nhân_viên y_tế .',
#  'Bệnh_nhân đến khám tại Bệnh_viện Y_học cổ_truyền TP HCM , ảnh chụp X - quang cho thấy có dấu_hiệu thâm_nhiễm 1/3 dưới đáy phổi .',
#  'Trước đó , CDC thành_phố ghi_nhận mẫu bệnh_phẩm lấy vào ngày thứ 20 sau xuất_viện của cô này , tức ngày 28/6 , tái dương_tính .',
#  'Những người ra viện chủ_yếu là du_học_sinh về nước , cách_ly tập_trung ngay tại các đơn_vị quân_đội , gồm bệnh_nhân số 164 , 165 , 180 , 181,182 , 230 , 240 .',
#  'Các trường_hợp liên_quan đến " bệnh_nhân 262 " được Trung_tâm kiểm_soát bệnh_tật tỉnh Bắc_Ninh lấy mẫu xét_nghiệm , dự_kiến có kết_quả vào tối 14/4 .',
#  'Ngày 9/8 , ông khám và nhập Bệnh_viện Thanh_Nhàn với chẩn_đoán viêm phổi nặng , ngày 10/8 lấy mẫu gửi Trung_tâm Kiểm_soát bệnh_tật TP. Hà_Nội , kết_quả lần một âm_tính .',
#  'Trước khi khởi bệnh , bệnh_nhân điều_trị cùng khoa tim_mạch can_thiệp Bệnh_viện Đà_Nẵng , nằm cùng phòng mẹ bệnh_nhân 416 và ra viện ngày 23 - 7 .',
#  'Theo đó , Bộ Y_tế cho biết bệnh_nhân thứ 46 là cô N.T.D. , 30 tuổi , tiếp_viên của Hãng Hàng không Việt_Nam ( Vietnam_Airlines ) , địa_chỉ ở Q.Thanh Xuân , Hà_Nội .',
#  'Trong khi đó , xét_nghiệm công_thức máu thấy tiểu_cầu hạ , kèm da xung huyết đỏ , lúc này xét_nghiệm test Dengue NS1 dương_tính .',
#  'BN 1050 - 1051 từ Philippines nhập_cảnh sân_bay Cần_Thơ trên chuyến bay VJ2527 ngày 6 - 9 , được cách_ly tập_trung ngay sau khi nhập_cảnh tại khu cách_ly của thành_phố Cần_Thơ .',
#  'Từ ngày năm đến ngày bảy : vẫn cảm_thấy khó thở , mất vị_giác và thính_giác nhưng các triệu_chứng khác dần suy_giảm " .',
#  'Theo ông Khánh , ngay từ khi vào viện , các bác_sĩ đã sàng_lọc , người tiếp_xúc đều có có đầy_đủ trang_phục bảo_hộ , tuy_nhiên do bệnh_nhân đang bị ung_thư máu thể mãn_tính , bạch_cầu chỉ còn 1/50 so với bình_thường , bị sang_chấn tâm_lý rất nặng nên bệnh_viện đã cử_nhân_viên y_tế và nhân_viên công_tác xã_hội đến hỗ_trợ .',
#  'Các bệnh_nhân xuất_viện gồm bệnh_nhân 525 ( 90 tuổi ) , 777 ( 62 tuổi ) , 910 ( 6 tuổi ) và bệnh_nhân 909 ( 38 tuổi ) , cả bốn cùng trú huyện Duy_Xuyên , Quảng_Nam .',
#  'Tại đây , ông T. đi xe_khách giường_nằm Hoà_Hiệp ( biển số 72 LD - 005 . 40 ) về TP Vị_Thanh .',
#  'Từ 7h3 0 - 8h3 0 ngày 5 - 8 , bệnh_nhân 861 đưa con gái đến Trạm y_tế xã Gio_Châu , huyện Gio_Linh để tiêm phòng cho con .',
#  'Đến tối 7 - 3 , ông S. đi TP Phan_Thiết cùng vợ và con .',
#  'Hôm sau cô đi khám tại Trung_tâm Y_tế Hàng_không , sau đó được chuyển vào Bệnh_viện Bệnh nhiệt_đới Trung_ương cơ_sở Đông_Anh , tại đây bệnh_nhân được cách_ly và lấy mẫu làm xét_nghiệm lần đầu cho kết_quả dương_tính nCoV .',
#  'Bệnh_nhân vẫn thở máy qua ống mở khí_quản , phổi còn tổn_thương nhưng oxy_hoá máu đã cải_thiện .',
#  'Điều đó cũng giải_thích tại_sao người hút thuốc và người có tiền_sử bệnh nền có chức_năng nội mô suy_yếu dễ nhiễm nCoV hơn .',
#  'Kết_quả xét nhiệm của Viện Vệ_sinh dịch_tễ Tây_Nguyên , nữ bệnh_nhân dương_tính nCoV .',
#  'Anh này tiền_sử bệnh thận mạn giai_đoạn cuối , suy tim , tăng huyết_áp , 12 năm thẩm phân phúc_mạc ( lọc máu qua phúc_mạc bụng ) .',
#  'Bệnh_nhân 788 , 789 tại Khánh_Hoà , ngày 5/8 từ Mexico ( quá_cảnh Nhật ) nhập_cảnh sân_bay Cam_Ranh trên chuyến bay VJ7837 , được cách_ly ngay tại Trung_tâm giáo_dục Quốc_phòng an_ninh thuộc Đại_học Nha_Trang .',
#  'Ông quá_cảnh Bangkok sau đó về Việt_Nam trên chuyến bay TG560 , số ghế 37E , cách_ly tập_trung tại Trường Quân_sự thị_xã Sơn_Tây .',
#  'Cùng ngày , Trung_tâm kiểm_soát bệnh_tật TP. HCM phát thông_báo khẩn đến khách_hàng từng đến quán bar Budha ( số 7 đường Thảo_Điền , phường Thảo_Điền , quận 2 ) trong vòng 14 ngày trước khẩn_trương liên_hệ với cơ_quan y_tế địa_phương gần nhất để được kiểm_tra sức_khoẻ và hướng_dẫn phòng_ngừa lây_nhiễm .',
#  'Theo đó , ca bệnh 1045 ( bệnh_nhân 1045 ) ghi nhận tại Hải Dương , là nam , 72 tuổi , có địa chỉ tại xã Thống Nhất , huyện Gia Lộc , Hải Dương .',
#  'Ông Trần_Thế Cương - bí_thư , chủ_tịch UBND quận Bắc Từ_Liêm - cho biết bệnh_nhân 345 trước đó cùng vợ và 3 con sống ở Romania .',
#  'Theo Bệnh_viện Đa_khoa Khu_vực Tây_Bắc_Nghệ_An , ngày 31 - 3 bệnh_viện này tiếp_nhận bệnh_nhân C.T.H. ( 47 tuổi , ngụ xóm 3 , xã Nghĩa Thuận ) với các triệu_chứng đau rát họng , ho_khan , không sốt .',
#  'Trung_tâm Kiểm_soát bệnh_tật tỉnh Quảng_Ninh lấy mẫu xét_nghiệm lần một ngày 3/6 , kết_quả âm_tính nCoV .',
#  'Ngày 11/8 , bệnh_nhân sốt ( nhiệt_độ từ 38 - 39 độ C ) kèm đau bụng âm_ỉ liên_tục vùng hạ sườn phải , không ho , không khó thở .',
#  'Quy_trình xét_nghiệm nCoV , ngoài triệu_chứng còn đòi_hỏi phải yếu_tố dịch_tễ nghi nhiễm ( đến từ vùng dịch , có tiếp_xúc với người bị nhiễm ) dẫn đến bỏ sót người_bệnh bị lây từ cộng_đồng , không xác_định được F0 ( ví_dụ như BN243 và 262 gần đây ) .',
#  'Bệnh_nhân thứ 21 là cán_bộ Viện_Hàn_lâm Khoa_học và Xã_hội Việt_Nam , đi cùng chuyến bay với Nhung .',
#  'Một biến_chứng rất nguy_hiểm của huyết khối tĩnh_mạch là tắc động_mạch phổi , làm tăng nguy_cơ tử_vong , đặc_biệt ở bệnh_nhân Covid - 19 có tổn_thương phổi và mắc kèm nhiều bệnh nền như " bệnh_nhân 456 " .',
#  'Bệnh_nhân 91 phi_công người Anh Ngày 18 - 3 : nhập_viện Bệnh_viện Bệnh nhiệt_đới TP. HCM 25 - 3 : Bắt_đầu thở oxy qua mặt_nạ 5 - 4 : Thở máy xâm_lấn 6 - 4 : Bắt_đầu sử_dụng ECMO 13 - 5 : Cả hai phổi xơ_hoá , chỉ còn 10% hoạt_động 18 - 5 : Phổi bắt_đầu phục_hồi 22 - 5 : Chuyển sang Bệnh_viện Chợ_Rẫy 27 - 5 : Có dấu_hiệu tỉnh 2 - 6 : Bắt_đầu thực_hiện được y_lệnh của bác_sĩ 4 - 6 : Ngưng dùng ECMO 9 - 6 : Tự ngồi dậy được 13 - 6 : Ngưng thở máy , tự thở hoàn_toàn trong 24 giờ 15 - 6 : Bắt_đầu đứng được và tập đi',
#  'Ngày 24/3 , anh từ Nga trở về Việt_Nam trên chuyến bay SU290 , ghế 49F , nhập_cảnh sân_bay Nội_Bài ngày 25/3 , cách_ly tập_trung tại Trường Đại_học FPT , Thạch_Thất , Hà_Nội .',
#  'Lịch_trình di_chuyển của bệnh_nhân 950 như sau : đi du_lịch Sa_Pa cùng gia_đình và nhà chị Q. ( ở số 36 Ngô_Quyền , TP Hải_Dương ) ngày 19 - 7 , nghỉ tại khách_sạn Sapa_Highland_Resort .',
#  '" Cùng ngày , " bệnh_nhân 433 " chuyển vào Bệnh_viện Đa_khoa Trung_ương Quảng_Nam để điều_trị tốt hơn " , ông Nguyễn_Văn_Hai , Giám_đốc Sở Y_tế Quảng_Nám nói .',
#  'Chiều 27/7 , cụ có dấu_hiệu mệt , sốt nên người thân thuê xe dịch_vụ chở đến Khoa_Cấp cứu , Bệnh_viện Đa_khoa khu_vực Quảng_Nam ( nơi có " bệnh_nhân 524 " điều_trị từ 25 đến 29/7 ) .',
#  'Thành_phố Sầm_Sơn hiện ghi_nhận một ca mắc Covid - 19 là " bệnh_nhân 748 " ở phố Nam_Bắc , phường Quảng_Vinh .',
#  'Bệnh_nhân 427 và 484 được chuyển đến Bệnh_viện Da_Liễu Đà_Nẵng cách_ly và tiếp_tục chạy thận nhân_tạo tại Bệnh_viện C Đà_Nẵng .',
#  'Theo Ban Chỉ_đạo Quốc_gia phòng_chống dịch COVID - 19 , bệnh_nhân 268 là nữ , 16 tuổi , quốc_tịch Việt_Nam , dân_tộc Mông , trú tại một thôn hẻo_lánh ở gần biên_giới giáp Trung_Quốc của huyện Đồng_Văn , tỉnh Hà_Giang .',
#  'Ngày 21/3 , cô sốt , được nhân_viên Trung_tâm Y_tế Hoàng_Mai đến nhà lấy mẫu xét_nghiệm , kết_quả dương_tính nCoV .',
#  'Theo thông_tin từ Công_an quận Tân_Bình , bệnh_nhân thứ 912 đã nhập_cảnh trái_phép cùng 7 người Trung_Quốc khác .',
#  '" Bệnh_nhân 123 " , nữ , 17 tuổi , sống tại Sarawar , Malaysia được 3 - 4 tháng nay .',
#  'Cũng trong phiên họp , lãnh_đạo quận Bắc_Từ_Liêm thông_tin có 2 trường_hợp ở Xuân_Đỉnh và Minh_Khai đi từ Đà_Nẵng về ngày 26 - 7 bị sốt cao .',
#  'Trước đó ngày 13 - 5 , kết_quả CT scan phổi bệnh_nhân 91 cho thấy toàn_bộ 2 lá phổi đã xơ_hoá đông_đặc , chỉ còn khoảng 10% vùng phổi còn hoạt_động .',
#  'Anh có người_nhà vào điều_trị tại khoa Ngoại tổng_hợp ( Bệnh_viện Đà_Nẵng ) từ ngày 21 đến 26/7 .',
#  'Trước đó lúc 15h ngày 9/8 , tỉnh Quảng_Trị quyết_định phong_toả tạm_thời tầng 6 nhà G , Bệnh_viện đa_khoa tỉnh Quảng_Trị , do đây là nơi điều_trị của " bệnh_nhân 832 " .',
#  'Chiều 31/7 , Bộ Y_tế cũng thông_báo tìm tất_cả người đến thăm , chăm_sóc bệnh_nhân hoặc đến khám , điều_trị tại Bệnh_viện Đà_Nẵng từ ngày 1/7 ; các hành_khách trên chuyến bay VN166 lúc 8h30 ngày 25/7 từ Đà_Nẵng về Hà_Nội , khẩn_trương liên_hệ với cơ_quan y_tế gần nhất để được tư_vấn , hỗ_trợ xét_nghiệm sàng_lọc nCoV .',
#  '" Bệnh_nhân có các bệnh_lý nền gồm tiểu_đường và cao huyết_áp cũng như bệnh tắc_nghẽn phổi mạn_tính .',
#  '" Bệnh_nhân 812 " , 62 tuổi , nhân_viên tiệm bánh pizza ở phố Trần_Thái_Tông , tổn_thương phổi nặng nhất , đến 70% .',
#  'Tối 10/8 , Ban chỉ_đạo phòng_chống dịch Covid - 19 thành_phố Đà_Nẵng cho biết , hai nữ điều_dưỡng vừa được Bộ Y_tế công_bố chiều nay là " bệnh_nhân 844 " và " bệnh_nhân 845 " , cùng làm_việc tại Khoa_Nội thận - Nội_tiết ( Bệnh_viện Đà_Nẵng ) .',
#  '" Thời_điểm bệnh_nhân chuyển đến Bệnh_viện Chợ_Rẫy ở Đà_Nẵng vẫn chưa phát_hiện ca bệnh đầu_tiên nhưng do nghi bệnh_nhân viêm phổi nhiễm_trùng nên chúng_tôi đã có sự cảnh_giác bằng cách đưa vào phòng cách_ly , trang_bị bảo_hộ .',
#  '" Bệnh_nhân 86 " và 87 là những nhân_viên y_tế đầu_tiên của Việt_Nam mắc Covid - 19 . Họ là hai điều_dưỡng làm_việc tại khu_vực khám sàng_lọc Trung_tâm Bệnh Nhiệt_đới , Bệnh_viện Bạch_Mai . " Bệnh_nhân 86 " từng đi TP HCM đến Phú_Quốc và về Hà_Nội .',
#  'Ngày 15 - 3 , bệnh_nhân về tới Việt_Nam trên chuyến bay của hãng hàng_không Vietnam_Airlines số_hiệu VN 50 , số ghế 10E .',
#  'Ngày 4/8 , lúc 7h45 bệnh_nhân hôn_mê , đồng_tử giãn , mất hoàn_toàn phản_xạ , gần một giờ sau tử_vong .',
#  'Vụ_việc xảy ra lúc 21h tối 23 - 7 , khi 2 phụ_nữ sử_dụng chứng_minh nhân_dân mang tên Hồ_Thị_Cẩm L. và Nguyễn_Thị_Nh . , đều có hộ_khẩu thường_trú tại ấp Tà_Tây , Phi_Thông , TP Rạch_Giá , Kiên_Giang làm thủ_tục đi chuyến bay VJ159 để đi từ Hà_Nội vào TP. HCM cất_cánh lúc 22h20 cùng ngày .',
#  'Qua xác_minh dịch_tễ ban_đầu của ngành Y_tế huyện Xuyên_Mộc , trong 2 ngày 18 - 8 và 30 - 8 , P. đi xe_khách của hãng xe Hai_Trâm lên TP. HCM để làm thủ_tục xuất_cảnh .',
#  'Trước đó , đã có 2 bệnh_viện Bạch_Mai , Hồng_Ngọc và 1 khoa của Bệnh_viện Xanh_Pôn bị cách_ly sau khi ghi_nhận bệnh_nhân hoặc có tiếp_xúc với bệnh_nhân COVID - 19 .',
#  'Ngày 5/6 , họ từ Nhật_Bản về sân_bay Đà_Nẵng trên chuyến bay VN319 , cách_ly tại Quảng_Nam .',
#  'Hiện 4 người Việt_Nam , bao_gồm cả nam thanh_niên trên , đang sống ở chùa Tokurinji .',
#  'Bệnh_nhân đi cùng bạn trai từ Thuỵ_Sĩ tới Dubai và về Việt_Nam ngày 12 - 3 trên chuyến bay EK392 từ Thuỵ_Sĩ quá_cảnh Dubai về Cảng_hàng_không sân_bay Tân_Sơn_Nhất , còn người bạn trai tới Hong_Kong , Trung_Quốc .',
#  'Hai bệnh_nhân còn lại được công_bố khỏi bệnh ở Trung_tâm Y_tế Huyện Hồng_Ngự , tỉnh Đồng_Tháp và Bệnh_viện Dã_chiến Củ_Chi .',
#  'Tối cùng ngày bệnh_nhân được chuyển vào Khoa y_học nhiệt_đới , Bệnh_viện Đà_Nẵng .',
#  'Trung_tâm Y_tế quận Hoàn_Kiếm đã lấy mẫu xét_nghiệm và đưa vào cách_ly tại trường Cao_đẳng nghề công_nghệ_cao Hà_Nội , quận Nam_Từ_Liêm .',
#  'Chị sống cùng chồng P.N.H. tại K1120 Trường_Chinh , tổ 11 , phường Hoà_Phát , quận Cẩm_Lệ , TP Đà_Nẵng .',
#  'Cô được xác_định dương_tính nCoV ngày 25/5 , điều_trị tại Bệnh_viện Dã_chiến Củ_chi , nhiều lần xét_nghiệm âm_tính nCoV .',
#  '9 bệnh_nhân tại Trung_tâm Y_tế Hoà_Vang gồm : 467 , 684 , 706 , 768 , 801 , 799 , 809 , 813 , 826 .',
#  'Tỉnh Thừa_Thiên_Huế đã ghi_nhận ca dương_tính nCoV trên địa_bàn và là " bệnh_nhân 30 " ở Việt_Nam .',
#  'Trong ngày 17 - 4 có 21 bệnh_nhân được công_bố khỏi bệnh , gồm 17 bệnh_nhân tại Bệnh_viện Bệnh nhiệt_đới trung_ương cơ_sở 2 , 3 bệnh_nhân tại Bệnh_viện Lao và bệnh phổi Trà_Vinh và 1 bệnh_nhân tại Bệnh_viện Đa_khoa huyện Nho_Quan , Ninh_Bình .',
#  'Theo bác_sĩ Chính , giãn cách bệnh_nhân suy thận mạn lọc máu , nghĩa_là chia bệnh_nhân thành nhiều nhóm nhỏ ngay từ khâu cách_ly đến lọc máu ; giám_sát không cho họ tiếp_xúc gần với nhau .',
#  ...]

# %%
model.to('cuda')

# %% [markdown]
# The process below predicts targets for 2k data samples in the dev set

# %%
predictions = []
references = []

# %%
for i in range(2000):
  print (i)
  sentence = eval_input_sequences[i]
  tokenized_input = tokenizer(sentence, return_tensors='pt', max_length=1024)
  input_ids = tokenized_input['input_ids'].to('cuda')
  attention_mask = tokenized_input['attention_mask'].to('cuda')

  outputs = model.generate(
      input_ids=input_ids, attention_mask=attention_mask, max_length=1024
      )
  labels = tokenizer.decode(outputs[0], clean_up_tokenization_spaces=True, skip_special_tokens=True)

  sentence = unidecode(sentence).lower()
  labels = unidecode(labels)
  flabels = word_labels(sentence, labels)
  predictions.append(flabels)
  references.append(eval_output_sequences[i].split())

# %%
eval_input_sequences[121]
# Out:
# 'Hai viện Bệnh Nhiệt_đới và Pasteur_TPHCM xét_nghiệm cho kết_quả có nCoV .'

# %% [markdown]
# # resultssss

# %% [markdown]
# Use seqeval framework introduced to calculate scores F1/precision/recall for every class entity and overall score for model performance

# %%
result = seqeval.compute(predictions=predictions, references=references)
result
# Out:
# {'AGE': {'precision': 0.9506849315068493,
#   'recall': 0.961218836565097,
#   'f1': 0.9559228650137742,
#   'number': 361},
#  'DATE': {'precision': 0.9740143369175627,
#   'recall': 0.985494106980961,
#   'f1': 0.9797205948625506,
#   'number': 1103},
#  'GENDER': {'precision': 0.9490909090909091,
#   'recall': 0.9422382671480144,
#   'f1': 0.9456521739130435,
#   'number': 277},
#  'JOB': {'precision': 0.7153846153846154,
#   'recall': 0.7045454545454546,
#   'f1': 0.7099236641221374,
#   'number': 132},
#  'LOCATION': {'precision': 0.9458668617410387,
#   'recall': 0.9448301059554256,
#   'f1': 0.9453481995978796,
#   'number': 2737},
#  'NAME': {'precision': 0.9545454545454546,
#   'recall': 0.8936170212765957,
#   'f1': 0.9230769230769231,
#   'number': 188},
#  'ORGANIZATION': {'precision': 0.8785714285714286,
#   'recall': 0.8929219600725953,
#   'f1': 0.8856885688568857,
#   'number': 551},
#  'PATIENT_ID': {'precision': 0.9803613511390417,
#   'recall': 0.9780564263322884,
#   'f1': 0.9792075323656336,
#   'number': 1276},
#  'SYMPTOM_AND_DISEASE': {'precision': 0.8562421185372006,
#   'recall': 0.8864229765013055,
#   'f1': 0.8710711994868505,
#   'number': 766},
#  'TRANSPORTATION': {'precision': 1.0,
#   'recall': 0.9885057471264368,
#   'f1': 0.9942196531791908,
#   'number': 87},
#  'overall_precision': 0.9385988279168886,
#  'overall_recall': 0.9423642685209949,
#  'overall_f1': 0.9404777792606432,
#  'overall_accuracy': 0.9790167546150703}
